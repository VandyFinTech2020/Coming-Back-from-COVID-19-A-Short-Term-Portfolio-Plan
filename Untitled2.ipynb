# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# connectionString = "dbname='project01' user='pgadmin@fintech-postgres' host='fintech-postgres.postgres.database.azure.com' password='CgYRz!)[4pfB' port='5432' sslmode='true'"

engine = create_engine(
    "postgresql://pgadmin@fintech-postgres:CgYRz!)[4pfB@fintech-postgres.postgres.database.azure.com:5432/project01")

query = "select * from portfolio;"
dfPortfolios = pd.read_sql(query, engine, index_col='portfolio_id')


def LoadCsvs(row):
    dfResult = pd.DataFrame()
    portfolio = row["portfolio_name"]
    path = "f:/_GIT/FinTech/Project01/"
    csvFeb = path + portfolio + "_feb.csv"
    csvApr = path + portfolio + "_apr.csv"
    dfFeb = pd.read_csv(csvFeb).dropna()
    dfApr = pd.read_csv(csvApr).dropna()
    inCovid = False
    for df_ in [dfFeb, dfApr]:
        for column in df_:
            if column == "Date":
                continue
            dfTmp = pd.DataFrame()
            dfTmp["date"] = df_["Date"].values
            dfTmp[column] = df_[column].values
            dfTmp = dfTmp.rename(columns={column: "close_price"})
            query = f"select * from ticker where ticker_name = '{column}';"
            dfTickers = pd.read_sql(query, engine)
            ticker_id = dfTickers["ticker_id"][0]
            dfTmp["ticker_id"] = ticker_id
            dfTmp["ticker_name"] = column
            dfTmp["covidineffect"] = inCovid
            print(dfTmp.head(2))
            dfResult = dfResult.append(dfTmp, ignore_index=True)
        inCovid = True
    return dfResult


dfMain = pd.DataFrame()
for i, row in dfPortfolios.iterrows():
    dfMain = dfMain.append(LoadCsvs(row), ignore_index=True)
print(dfMain.count())
print(dfMain.head())


dfMain = dfMain[["ticker_id", "date",
                 "close_price", "ticker_name", "covidineffect"]]
print(dfMain.head(2))
# Out:
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        41.85          8         ADM          False
# 1  2/20/2019        41.97          8         ADM          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        24.01         13         CAG          False
# 1  2/20/2019        24.03         13         CAG          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        43.30          2         HRL          False
# 1  2/20/2019        43.13          2         HRL          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        62.94          3         TSN          False
# 1  2/20/2019        63.60          3         TSN          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        41.85          8         ADM           True
# 1  2/20/2019        41.97          8         ADM           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        24.01         13         CAG           True
# 1  2/20/2019        24.03         13         CAG           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        43.30          2         HRL           True
# 1  2/20/2019        43.13          2         HRL           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        62.94          3         TSN           True
# 1  2/20/2019        63.60          3         TSN           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       348.43         12        CHTR          False
# 1  2/20/2019       349.76         12        CHTR          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        37.55         20       CMCSA          False
# 1  2/20/2019        37.79         20       CMCSA          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        30.63         16           T          False
# 1  2/20/2019        30.85         16           T          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        55.44          6          VZ          False
# 1  2/20/2019        55.76          6          VZ          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       348.43         12        CHTR           True
# 1  2/20/2019       349.76         12        CHTR           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        37.55         20       CMCSA           True
# 1  2/20/2019        37.79         20       CMCSA           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        30.63         16           T           True
# 1  2/20/2019        30.85         16           T           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        55.44          6          VZ           True
# 1  2/20/2019        55.76          6          VZ           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        29.13          5         BAC          False
# 1  2/20/2019        29.41          5         BAC          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       198.67          9          GS          False
# 1  2/20/2019       198.60          9          GS          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        95.02          4        PYPL          False
# 1  2/20/2019        94.73          4        PYPL          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       144.44          7           V          False
# 1  2/20/2019       144.73          7           V          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        29.13          5         BAC           True
# 1  2/20/2019        29.41          5         BAC           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       198.67          9          GS           True
# 1  2/20/2019       198.60          9          GS           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        95.02          4        PYPL           True
# 1  2/20/2019        94.73          4        PYPL           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       144.44          7           V           True
# 1  2/20/2019       144.73          7           V           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       142.69         15      ETHUSD          False
# 1  2/20/2019       147.19         15      ETHUSD          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019      3888.01         18      BTCUSD          False
# 1  2/20/2019      3938.99         18      BTCUSD          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       126.70         10         GLD          False
# 1  2/20/2019       126.48         10         GLD          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        15.02          1         SLV          False
# 1  2/20/2019        15.07          1         SLV          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       142.69         15      ETHUSD           True
# 1  2/20/2019       147.19         15      ETHUSD           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019      3888.01         18      BTCUSD           True
# 1  2/20/2019      3938.99         18      BTCUSD           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       126.70         10         GLD           True
# 1  2/20/2019       126.48         10         GLD           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        15.02          1         SLV           True
# 1  2/20/2019        15.07          1         SLV           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        75.00         14         ABT          False
# 1  2/20/2019        75.54         14         ABT          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       135.69         11         JNJ          False
# 1  2/20/2019       136.35         11         JNJ          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        79.24         17         MRK          False
# 1  2/20/2019        79.43         17         MRK          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019         42.6         19         PFE          False
# 1  2/20/2019         42.2         19         PFE          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        75.00         14         ABT           True
# 1  2/20/2019        75.54         14         ABT           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019       135.69         11         JNJ           True
# 1  2/20/2019       136.35         11         JNJ           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        79.24         17         MRK           True
# 1  2/20/2019        79.43         17         MRK           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019         42.6         19         PFE           True
# 1  2/20/2019         42.2         19         PFE           True
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019      2779.76         21       SP500          False
# 1  2/20/2019      2784.70         21       SP500          False
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019      2779.76         21       SP500           True
# 1  2/20/2019      2784.70         21       SP500           True
# date             11651
# close_price      11651
# ticker_id        11651
# ticker_name      11651
# covidineffect    11651
# dtype: int64
#         date  close_price  ticker_id ticker_name  covidineffect
# 0  2/19/2019        41.85          8         ADM          False
# 1  2/20/2019        41.97          8         ADM          False
# 2  2/21/2019        42.57          8         ADM          False
# 3  2/22/2019        42.49          8         ADM          False
# 4  2/25/2019        42.43          8         ADM          False
#    ticker_id       date  close_price ticker_name  covidineffect
# 0          8  2/19/2019        41.85         ADM          False
# 1          8  2/20/2019        41.97         ADM          False

# %%
print(dfMain.count())
# Out:
# ticker_id        11651
# date             11651
# close_price      11651
# ticker_name      11651
# covidineffect    11651
# dtype: int64

# %%
# dfMain.to_sql('price', engine, if_exists='replace', index = False)
dfMain.to_sql('price', engine, if_exists='append', index=False)

# %%
for _, row in dfMain
